# %%
# %pip install timm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import timm
from tqdm import tqdm

# %%
# Ensure torch is imported before using it
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

train_val_dir = r"C:\Users\praha\Downloads\EPICS_1\Train_Validation sets"
test_dir = r"C:\Users\praha\Downloads\EPICS_1\Independent Test Set\Independent Test Set"
# Out:
# Using device: cpu

# %%
# Ensure transforms is imported
from torchvision import transforms

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
# Ensure all necessary imports and variables are defined
import os
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# Define directory paths
train_val_dir = r"C:\Users\praha\Downloads\EPICS_1\Train_Validation sets"
test_dir = r"C:\Users\praha\Downloads\EPICS_1\Independent Test Set\Independent Test Set"

# Define transforms
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# Path to the folder containing class folders
train_val_path = os.path.join(train_val_dir)

# Load the full dataset
full_dataset = datasets.ImageFolder(
    train_val_path,
    transform=train_transform
)

# Split into train and validation sets (e.g., 80% train, 20% val)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# Test dataset
test_dataset = datasets.ImageFolder(
    test_dir,
    transform=val_transform
)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

NUM_CLASSES = len(full_dataset.classes)

print("Classes:", full_dataset.classes)
# Out:
# Classes: ['Train_Validation sets']

# %%
# Ensure all necessary imports and variables are defined
import timm
import torch

# Define device (if not already defined)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define NUM_CLASSES (example value, update as needed)
# NUM_CLASSES should match the number of classes in your dataset
NUM_CLASSES = 3  # Replace with actual value if needed

# Create and move model to device
model = timm.create_model(
    "convnextv2_tiny",
    pretrained=True,
    num_classes=NUM_CLASSES
)

model = model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# c:\Users\praha\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:130: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\praha\.cache\huggingface\hub\models--timm--convnextv2_tiny.fcmae_ft_in22k_in1k. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
# Ensure all necessary imports and variables are defined
import torch
import torch.nn as nn
import torch.optim as optim

# Assume model is already defined (from previous cell)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

# %%
# Import nn before using it
import torch.nn as nn

criterion = nn.CrossEntropyLoss()

# %%
# Import tqdm before using it
from tqdm import tqdm

# %%
# Combined Data Loading and Training Cell
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import timm
from tqdm import tqdm
import matplotlib.pyplot as plt

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Directory paths
train_val_dir = r"C:\Users\praha\Downloads\EPICS_1\Train_Validation sets"
test_dir = r"C:\Users\praha\Downloads\EPICS_1\Independent Test Set\Independent Test Set"

# Transforms
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                     [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                     [0.229, 0.224, 0.225])
])

# Load dataset
train_val_path = os.path.join(train_val_dir)
full_dataset = datasets.ImageFolder(train_val_path, transform=train_transform)

# Split into train and validation sets
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# Test dataset (not used in training, but defined for completeness)
test_dataset = datasets.ImageFolder(test_dir, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

NUM_CLASSES = len(full_dataset.classes)
print("Classes:", full_dataset.classes)

# Model, loss, optimizer
model = timm.create_model("convnextv2_tiny", pretrained=True, num_classes=NUM_CLASSES)
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

# Training loop
EPOCHS = 20
train_acc_list = []
val_acc_list = []

for epoch in range(EPOCHS):
    model.train()
    train_correct = 0
    train_total = 0
    train_loss = 0
    for images, labels in tqdm(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()
    train_acc = 100 * train_correct / train_total
    train_acc_list.append(train_acc)
    # Validation
    model.eval()
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
    val_acc = 100 * val_correct / val_total
    val_acc_list.append(val_acc)
    print(f"\nEpoch [{epoch+1}/{EPOCHS}]")
    print(f"Train Accuracy: {train_acc:.2f}%")
    print(f"Validation Accuracy: {val_acc:.2f}%")

# Plot train vs validation accuracy to check for overfitting
plt.figure(figsize=(8,5))
plt.plot(range(1, EPOCHS+1), train_acc_list, label='Train Accuracy')
plt.plot(range(1, EPOCHS+1), val_acc_list, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train vs Validation Accuracy')
plt.legend()
plt.show()

# Overfitting indication
if max(train_acc_list) - max(val_acc_list) > 5:
    print('Warning: Model may be overfitting (train accuracy much higher than validation accuracy).')
else:
    print('No significant overfitting detected.')
# Out:
# Using device: cpu
# Classes: ['Train_Validation sets']
# 100%|██████████| 74/74 [09:27<00:00,  7.67s/it]
# Epoch [1/20]
# Train Accuracy: 100.00%
# Validation Accuracy: 100.00%
# 100%|██████████| 74/74 [09:19<00:00,  7.57s/it]
# Epoch [2/20]
# Train Accuracy: 100.00%
# Validation Accuracy: 100.00%
# 100%|██████████| 74/74 [09:20<00:00,  7.58s/it]
# Epoch [3/20]
# Train Accuracy: 100.00%
# Validation Accuracy: 100.00%
# 100%|██████████| 74/74 [09:20<00:00,  7.58s/it]
# Epoch [4/20]
# Train Accuracy: 100.00%
# Validation Accuracy: 100.00%
# 100%|██████████| 74/74 [09:18<00:00,  7.55s/it]
# Epoch [5/20]
# Train Accuracy: 100.00%
# Validation Accuracy: 100.00%
# 100%|██████████| 74/74 [09:20<00:00,  7.57s/it]
# Epoch [6/20]
# Train Accuracy: 100.00%
# Validation Accuracy: 100.00%
# 100%|██████████| 74/74 [09:20<00:00,  7.58s/it]
# Epoch [7/20]
# Train Accuracy: 100.00%
# Validation Accuracy: 100.00%
# 100%|██████████| 74/74 [09:17<00:00,  7.54s/it]
# Epoch [8/20]
# ...

# %%
import numpy as np
from sklearn.metrics import accuracy_score

# Ensure torch is imported before using it
import torch

# Ensure all_preds and all_labels are defined before using them
try:
    all_preds
    all_labels
except NameError:
    # If not defined, run prediction on test_loader to get them
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.numpy())

# Convert to numpy arrays
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)

# ===============================
# 1️⃣ Testing Accuracy
# ===============================
test_accuracy = accuracy_score(all_labels, all_preds) * 100
print(f"\nTesting Accuracy (Independent Test Set): {test_accuracy:.2f}%")

# ===============================
# 2️⃣ Overall Accuracy
# ===============================
# For classification problems:
# Overall Accuracy = Total Correct Predictions / Total Samples

correct = np.sum(all_preds == all_labels)
total = len(all_labels)

overall_accuracy = (correct / total) * 100
print(f"Overall Model Accuracy: {overall_accuracy:.2f}%")

# ===============================
# 3️⃣ Error Rate
# ===============================
error_rate = 100 - overall_accuracy
print(f"Model Error Rate: {error_rate:.2f}%")
# Out:
# Testing Accuracy (Independent Test Set): nan%
# Overall Model Accuracy: nan%
# Model Error Rate: nan%
# c:\Users\praha\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:562: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# c:\Users\praha\anaconda3\Lib\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\praha\AppData\Local\Temp\ipykernel_19780\1578119344.py:42: RuntimeWarning: invalid value encountered in scalar divide
#   overall_accuracy = (correct / total) * 100

# %%
# Ensure torch and model are defined before saving
import torch
try:
    model
except NameError:
    # If model is not defined, create a new instance (do not try to load weights if file does not exist)
    import timm
    NUM_CLASSES = 3  # Update if needed
    model = timm.create_model("convnextv2_tiny", pretrained=False, num_classes=NUM_CLASSES)
torch.save(model.state_dict(), "convnextv2_model.pth")
print("ConvNeXt V2 Model Saved Successfully!")
# Out:
# ConvNeXt V2 Model Saved Successfully!

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import timm
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Path
test_dir = r"C:\Users\praha\Downloads\EPICS_1\Independent Test Set"

# Transform
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

test_dataset = datasets.ImageFolder(test_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

NUM_CLASSES = 3  # Ensure this matches the number of classes used in training and saving the model

# Load model with correct number of classes
model = timm.create_model("convnextv2_tiny", pretrained=False, num_classes=NUM_CLASSES)
state_dict = torch.load("convnextv2_model.pth")
# Remove classifier weights if shape mismatch (for transfer learning or class count change)
model_state = model.state_dict()
for key in list(state_dict.keys()):
    if key in model_state and state_dict[key].shape != model_state[key].shape:
        print(f"Skipping loading parameter: {key} due to shape mismatch: {state_dict[key].shape} vs {model_state[key].shape}")
        del state_dict[key]
model.load_state_dict(state_dict, strict=False)
model = model.to(device)
model.eval()
# Out:
# ConvNeXt(
#   (stem): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#     (1): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#   )
#   (stages): Sequential(
#     (0): ConvNeXtStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): ConvNeXtBlock(
#           (conv_dw): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (mlp): GlobalResponseNormMlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (grn): GlobalResponseNorm()
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (shortcut): Identity()
#           (drop_path): Identity()
#         )
#         (1): ConvNeXtBlock(
# ...

# %%
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)

        probs = torch.softmax(outputs, dim=1)

        _, predicted = torch.max(outputs, 1)

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.numpy())
        all_probs.extend(probs.cpu().numpy())

accuracy = 100 * np.sum(np.array(all_preds)==np.array(all_labels)) / len(all_labels)

print("Independent Test Accuracy: {:.2f}%".format(accuracy))
print("\nClassification Report:\n")
# Ensure the number of unique labels matches the number of class names
import numpy as np
from sklearn.metrics import classification_report

unique_labels = np.unique(np.concatenate([all_labels, all_preds]))
if len(unique_labels) != len(test_dataset.classes):
    print(f"Warning: Number of unique labels ({len(unique_labels)}) does not match number of class names ({len(test_dataset.classes)}). Adjusting target_names.")
    target_names = [str(cls) for cls in unique_labels]
else:
    target_names = test_dataset.classes
print(classification_report(all_labels, all_preds, target_names=target_names))
# Out:
# Independent Test Accuracy: 16.19%
#
# Classification Report:
#
# ...
#               precision    recall  f1-score   support
#
#            0       1.00      0.16      0.28      1050
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.16      1050
#    macro avg       0.50      0.08      0.14      1050
# weighted avg       1.00      0.16      0.28      1050
# c:\Users\praha\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\praha\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=test_dataset.classes,
            yticklabels=test_dataset.classes)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - ConvNeXt V2")
plt.show()

# %%
y_true_bin = label_binarize(all_labels, classes=range(NUM_CLASSES))
all_probs = np.array(all_probs)

plt.figure()

# Ensure we do not exceed the available class names
num_classes_to_plot = min(NUM_CLASSES, len(test_dataset.classes), y_true_bin.shape[1], all_probs.shape[1])
for i in range(num_classes_to_plot):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], all_probs[:, i])
    roc_auc = auc(fpr, tpr)
    class_name = test_dataset.classes[i] if i < len(test_dataset.classes) else str(i)
    plt.plot(fpr, tpr, label=f"{class_name} (AUC = {roc_auc:.2f})")

plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - ConvNeXt V2")
plt.legend()
plt.show()
# Out:
# c:\Users\praha\anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(

# %%
import torchvision
import matplotlib.pyplot as plt

# Get one batch
images, labels = next(iter(test_loader))
images = images.to(device)

with torch.no_grad():
    outputs = model(images)
    _, preds = torch.max(outputs, 1)

images = images.cpu()

# Unnormalize
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])

def imshow(img):
    img = img.numpy().transpose((1,2,0))
    img = std * img + mean
    img = np.clip(img, 0, 1)
    return img

plt.figure(figsize=(12,8))

num_images = min(12, images.shape[0], len(preds), len(labels))
for i in range(num_images):
    plt.subplot(3,4,i+1)
    plt.imshow(imshow(images[i]))
    pred_label = test_dataset.classes[preds[i]] if preds[i] < len(test_dataset.classes) else str(preds[i])
    true_label = test_dataset.classes[labels[i]] if labels[i] < len(test_dataset.classes) else str(labels[i])
    plt.title(f"P:{pred_label}\nT:{true_label}")
    plt.axis("off")

plt.suptitle("Prediction Grid - ConvNeXt V2")
plt.tight_layout()
plt.show()

# %%
convnext_acc = 92.3   # replace with your value
convnextv2_acc = accuracy

models = ["ConvNeXt", "ConvNeXt V2"]
scores = [convnext_acc, convnextv2_acc]

plt.figure()
plt.bar(models, scores)
plt.ylabel("Accuracy (%)")
plt.title("Model Comparison")
plt.show()
